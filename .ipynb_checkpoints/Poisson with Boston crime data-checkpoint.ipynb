# %%
# ref https://www.kaggle.com/ankkur13/boston-crime-data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load csv file into pandas
crime = pd.read_csv('crime.csv', encoding='cp1252')
# filter and get only bank robbery
bankrobcrime = crime[crime['OFFENSE_DESCRIPTION'] == 'ROBBERY - BANK']
# change string in dataset into datetime and set as a index
bankrobcrime.index = pd.to_datetime(bankrobcrime['OCCURRED_ON_DATE'])
# sort the dataset by datetime
bankrobcrime = bankrobcrime.sort_index(axis = 0) 
# see the head
bankrobcrime.head()
# Out:
#                     INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# OCCURRED_ON_DATE
# 2015-06-19 07:21:00      I152050714           351            Robbery
# 2015-07-07 13:04:00      I152056009           351            Robbery
# 2015-07-14 15:28:00      I152058208           351            Robbery
# 2015-07-24 13:20:00      I152061210           351            Robbery
# 2015-07-28 20:20:00      I152062382           351            Robbery
#
#                     OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# OCCURRED_ON_DATE
# 2015-06-19 07:21:00      ROBBERY - BANK       A1             99      NaN
# 2015-07-07 13:04:00      ROBBERY - BANK       B2            257      NaN
# 2015-07-14 15:28:00      ROBBERY - BANK       C6            213      NaN
# 2015-07-24 13:20:00      ROBBERY - BANK      D14            771      NaN
# 2015-07-28 20:20:00      ROBBERY - BANK       A7             12      NaN
#
#                         OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# OCCURRED_ON_DATE
# 2015-06-19 07:21:00  2015-06-19 07:21:00  2015      6      Friday     7
# 2015-07-07 13:04:00  2015-07-07 13:04:00  2015      7     Tuesday    13
# 2015-07-14 15:28:00  2015-07-14 15:28:00  2015      7     Tuesday    15
# 2015-07-24 13:20:00  2015-07-24 13:20:00  2015      7      Friday    13
# 2015-07-28 20:20:00  2015-07-28 20:20:00  2015      7     Tuesday    20
#
#                      UCR_PART         STREET        Lat       Long  \
# OCCURRED_ON_DATE
# 2015-06-19 07:21:00  Part One       KILBY ST  42.358622 -71.055745
# 2015-07-07 13:04:00  Part One    COLUMBIA RD  42.316860 -71.065275
# 2015-07-14 15:28:00  Part One     W BROADWAY  42.336112 -71.046654
# 2015-07-24 13:20:00  Part One  WASHINGTON ST  42.349111 -71.155273
# 2015-07-28 20:20:00  Part One  BENNINGTON ST  42.385585 -71.010091
#
#                                         Location
# OCCURRED_ON_DATE
# 2015-06-19 07:21:00  (42.35862221, -71.05574534)
# 2015-07-07 13:04:00  (42.31685976, -71.06527513)
# 2015-07-14 15:28:00  (42.33611200, -71.04665434)
# 2015-07-24 13:20:00  (42.34911090, -71.15527344)
# 2015-07-28 20:20:00  (42.38558494, -71.01009088)

# %%
datelist = bankrobcrime.index.tolist()
noofevent = len(datelist)
diftime = datelist[len(datelist)-1]-datelist[0]

tatoltime = diftime.total_seconds() / 60
rateofarrivelinminute = noofevent/tatoltime # per minute

tatoltime = diftime.total_seconds() / 3600
rateofarrivelinhour = noofevent/tatoltime # per an hour

tatoltime = diftime.total_seconds() / (3600*24)
rateofarrivelinday = noofevent/tatoltime # per an day
print("number of robbery =",noofevent)
print("time range",diftime)
print("time range in hours",diftime.total_seconds() / 3600)
print("rate of robbery per minute",rateofarrivelinminute)
print("rate of robbery per hour",rateofarrivelinhour)
print("average hours between a robberry",1/rateofarrivelinhour)
# Out:
# number of robbery = 181
# time range 1127 days 07:51:00
# time range in hours 27055.85
# rate of robbery per minute 0.00011149775988064195
# rate of robbery per hour 0.0066898655928385176
# average hours between a robberry 149.47983425414364

# %%
from math import exp, factorial
# formula P(k,t) = (((lamda*tau)**k)*exp((-lamda)*tau))/factorial(k)
# k is number of event we expect
# lamda is rate of occourance
# tau is amount of time we expect
# wait more than 120 hour
k = 1 # 1 robbery
lamda = rateofarrivelinhour # number of robbery in one hour
tau = 150 # number of hours we expect robbery to happend
p = (((lamda*tau)**k)*exp((-lamda)*tau))/factorial(k) # probability
print(p)
# Out:
# 0.3678772189545955

# %%
# ploting graph
# keep multiple tua
problist = []
tau = [90,180,300,450,700,1000,1500]
lamda = rateofarrivelinhour # number of robbery in one hour
for i in range(0,7) :
    eachproblist = []
    for k in range(0,15):
        eachproblist.append((((lamda*tau[i])**k)*exp((-lamda)*tau[i]))/factorial(k))
    problist.append(eachproblist)

# check first tua
print("max probability",max(problist[0]))
print("probability peak at tua =",problist[0].index(max(problist[0])))
print("sum of all probability =",sum(problist[0]))
plt.figure(figsize=(20,10))
for i in range(0,len(problist)) :
    plt.plot(problist[i], label="tau = " + str(tau[i]))
plt.legend()
# Out:
# max probability 0.5476669658337792
# probability peak at tua = 0
# sum of all probability = 0.9999999999999999

# %%
# ploting graph time before first arrivel (Erlang)
problist2 = []
k = 1 # 1 robbery
lamda = rateofarrivelinhour # number of robbery in one hour
for i in range(0,1000):
    tau = i
    problist2.append((lamda**k)*(tau**(k-1))*exp((-lamda)*tau)/factorial(k-1))
print("max probability",max(problist2))
print("probability peak at tua =",problist2.index(max(problist2)))
print("sum of all probability =",sum(problist2))
plt.figure(figsize=(20,10))
plt.plot(problist2)
# Out:
# max probability 0.0066898655928385176
# probability peak at tua = 0
# sum of all probability = 1.0021010485346822

# %%
# ploting graph waiting time
problist2 = []
lamda = rateofarrivelinhour # number of robbery in one hour
for i in range(1,6):
    eachproblist2 = []
    k = i # 1 robbery
    for j in range(0,1000):
        tau = j
        eachproblist2.append((lamda**k)*(tau**(k-1))*exp((-lamda)*tau)/factorial(k-1))
    problist2.append(eachproblist2)

# check k = 1
print("max probability",max(problist2[0]))
print("probability peak at tua =",problist2[0].index(max(problist2[0])))
print("sum of all probability =",sum(problist2[0]))
plt.figure(figsize=(20,10))
for i in range(0,len(problist2)) :
    plt.plot(problist2[i], label="k = " + str(i+1))
plt.legend()
# Out:
# max probability 0.0066898655928385176
# probability peak at tua = 0
# sum of all probability = 1.0021010485346822

# %%
# ploting graph waiting time less than and prob
problist3 = []
k = 1 # 1 robbery
lamda = rateofarrivelinhour # number of robbery in one hour
for i in range(0,1000):
    tau = i
    problist3.append(1 - exp((-lamda)*tau))
print("max probability",max(problist3))
print("probability peak at tua =",problist3.index(max(problist3)))
print("sum of all probability =",sum(problist3))
plt.figure(figsize=(20,10))
plt.plot(problist3)
# Out:
# max probability 0.9987482037100442
# probability peak at tua = 999
# sum of all probability = 850.2061013591313
